# %%
import numpy as np

# Seasons
Seasons = ["2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014"]
sdict = {"2005": 0, "2006": 1, "2007": 2, "2008": 3, "2009": 4, "2010": 5, "2011": 6, "2012": 7, "2013": 8, "2014": 9}

# Players
Players = ["KobeBryant", "JoeJohnson", "LebronJames", "CarmeloAnthony", "DwightHoward", "ChrisBosh", "ChrisPaul"]
Pdict = {"KobeBryant": 0, "JoeJohnson": 1, "LebronJames": 2, "CarmeloAnthony": 3, "DwightHoward": 4, "ChrisBosh": 5, "ChrisPaul": 6}

# Salaries
kobe_bryant_salaries = [15.95 * 10**6, 17.72 * 10**6, 19.49 * 10**6, 21.26 * 10**6, 23.03 * 10**6, 24.81 * 10**6, 25.24 * 10**6, 27.85 * 10**6, 30.45 * 10**6, 30.45 * 10**6]
lebron_james_salaries = [4.62 * 10**6, 5.83 * 10**6, 13.04 * 10**6, 14.41 * 10**6, 15.78 * 10**6, 16.82 * 10**6, 16.02 * 10**6, 17.55 * 10**6, 19.07 * 10**6, 20.59 * 10**6]
joe_johnson_salaries = [4.50 * 10**6, 4.90 * 10**6, 5.36 * 10**6, 6.05 * 10**6, 14.98 * 10**6, 15.22 * 10**6, 18.03 * 10**6, 19.75 * 10**6, 21.47 * 10**6, 23.18 * 10**6]
carmelo_anthony_salaries = [3.71 * 10**6, 4.69 * 10**6, 13.04 * 10**6, 14.41 * 10**6, 15.78 * 10**6, 17.14 * 10**6, 18.52 * 10**6, 19.45 * 10**6, 21.39 * 10**6, 22.45 * 10**6]
dwight_howard_salaries = [4.17 * 10**6, 4.46 * 10**6, 5.37 * 10**6, 13.76 * 10**6, 15.20 * 10**6, 16.64 * 10**6, 17.89 * 10**6, 19.26 * 10**6, 20.51 * 10**6, 21.44 * 10**6]
chris_bosh_salaries = [3.13 * 10**6, 4.18 * 10**6, 12.05 * 10**6, 14.41 * 10**6, 15.78 * 10**6, 16.02 * 10**6, 16.02 * 10**6, 17.55 * 10**6, 19.07 * 10**6, 20.59 * 10**6]
chris_paul_salaries = [3.14 * 10**6, 3.38 * 10**6, 4.57 * 10**6, 13.75 * 10**6, 14.94 * 10**6, 15.80 * 10**6, 16.36 * 10**6, 17.78 * 10**6, 18.67 * 10**6, 20.06 * 10**6]

salary = np.array([kobe_bryant_salaries, lebron_james_salaries, joe_johnson_salaries, carmelo_anthony_salaries, dwight_howard_salaries, chris_bosh_salaries, chris_paul_salaries])

# Number of Games Played
lebron_james_games = [25, 28, 30, 27, 35, 29, 32, 34, 28, 31]
joe_johnson_games = [20, 22, 24, 23, 21, 25, 26, 23, 22, 24]
kobe_bryant_games = [33, 35, 40, 38, 32, 34, 39, 37, 36, 34]
carmelo_anthony_games = [29, 31, 32, 28, 30, 33, 34, 31, 29, 30]
dwight_howard_games = [18, 22, 20, 23, 21, 19, 20, 24, 21, 22]
chris_bosh_games = [26, 27, 25, 28, 24, 27, 29, 30, 26, 28]
chris_paul_games = [23, 25, 27, 26, 24, 28, 29, 26, 27, 25]

Games = np.array([lebron_james_games, joe_johnson_games, kobe_bryant_games, carmelo_anthony_games, dwight_howard_games, chris_bosh_games, chris_paul_games])

# Number of Minutes Played
lebron_james_minutes = [35, 38, 37, 34, 40, 36, 39, 41, 33, 37]
joe_johnson_minutes = [30, 32, 31, 29, 28, 33, 34, 30, 31, 32]
kobe_bryant_minutes = [38, 40, 42, 41, 35, 39, 41, 40, 39, 37]
carmelo_anthony_minutes = [34, 36, 35, 33, 34, 37, 39, 34, 32, 33]
dwight_howard_minutes = [28, 30, 29, 31, 27, 29, 28, 32, 30, 29]
chris_bosh_minutes = [33, 34, 32, 35, 31, 34, 36, 37, 33, 34]
chris_paul_minutes = [32, 33, 34, 31, 30, 35, 36, 31, 32, 30]

Minutes = np.array([lebron_james_minutes, joe_johnson_minutes, kobe_bryant_minutes, carmelo_anthony_minutes, dwight_howard_minutes, chris_bosh_minutes, chris_paul_minutes])

# Field goals made by each player over 10 games
lebron_james_field_goals = [10, 12, 11, 9, 15, 14, 13, 16, 12, 11]
joe_johnson_field_goals = [8, 9, 10, 11, 7, 10, 9, 8, 10, 11]
kobe_bryant_field_goals = [15, 14, 18, 17, 16, 20, 19, 18, 17, 16]
carmelo_anthony_field_goals = [11, 12, 13, 10, 11, 14, 15, 12, 10, 13]
dwight_howard_field_goals = [5, 6, 7, 8, 6, 5, 7, 6, 8, 7]
chris_bosh_field_goals = [8, 9, 8, 7, 10, 9, 11, 10, 9, 8]
chris_paul_field_goals = [9, 10, 11, 8, 7, 12, 11, 10, 9, 8]

FieldGoals = np.array([lebron_james_field_goals, joe_johnson_field_goals, kobe_bryant_field_goals, carmelo_anthony_field_goals, dwight_howard_field_goals, chris_bosh_field_goals, chris_paul_field_goals])

# Field Goal Attempts by each player over 10 games
lebron_james_field_goal_attempts = [20, 22, 23, 18, 24, 21, 20, 26, 19, 18]
joe_johnson_field_goal_attempts = [17, 18, 19, 20, 15, 17, 18, 16, 17, 19]
kobe_bryant_field_goal_attempts = [30, 32, 35, 34, 33, 36, 37, 35, 33, 31]
carmelo_anthony_field_goal_attempts = [21, 23, 22, 20, 21, 24, 25, 22, 21, 22]
dwight_howard_field_goal_attempts = [8, 9, 10, 12, 10, 9, 10, 9, 11, 10]
chris_bosh_field_goal_attempts = [14, 15, 13, 12, 16, 15, 17, 16, 14, 13]
chris_paul_field_goal_attempts = [13, 14, 15, 12, 10, 16, 15, 14, 13, 12]

FieldGoalAttempts = np.array([lebron_james_field_goal_attempts, joe_johnson_field_goal_attempts, kobe_bryant_field_goal_attempts, carmelo_anthony_field_goal_attempts, dwight_howard_field_goal_attempts, chris_bosh_field_goal_attempts, chris_paul_field_goal_attempts])

# Free Throws by each player over 10 games
lebron_james_free_throws = [6, 7, 8, 6, 10, 9, 8, 10, 7, 6]
joe_johnson_free_throws = [4, 5, 6, 5, 4, 6, 5, 4, 6, 5]
kobe_bryant_free_throws = [9, 10, 11, 12, 11, 13, 12, 11, 10, 9]
carmelo_anthony_free_throws = [7, 8, 9, 6, 7, 9, 10, 8, 6, 7]
dwight_howard_free_throws = [3, 4, 5, 6, 4, 3, 5, 4, 6, 5]
chris_bosh_free_throws = [6, 7, 5, 4, 8, 7, 9, 8, 6, 5]
chris_paul_free_throws = [5, 6, 7, 5, 4, 8, 7, 6, 5, 4]

FreeThrows = np.array([lebron_james_free_throws, joe_johnson_free_throws, kobe_bryant_free_throws, carmelo_anthony_free_throws, dwight_howard_free_throws, chris_bosh_free_throws, chris_paul_free_throws])

# Free Throw Attempts by each player over 10 games
lebron_james_free_throw_attempts = [8, 9, 10, 7, 12, 10, 9, 12, 9, 8]
joe_johnson_free_throw_attempts = [6, 7, 8, 7, 6, 8, 7, 6, 8, 7]
kobe_bryant_free_throw_attempts = [12, 13, 14, 15, 14, 16, 15, 14, 13, 12]
carmelo_anthony_free_throw_attempts = [9, 10, 11, 8, 9, 11, 12, 9, 8, 9]
dwight_howard_free_throw_attempts = [5, 6, 7, 8, 6, 5, 7, 6, 8, 7]
chris_bosh_free_throw_attempts = [8, 9, 7, 6, 10, 9, 11, 10, 8, 7]
chris_paul_free_throw_attempts = [7, 8, 9, 7, 6, 10, 9, 8, 7, 6]

FreeThrowAttempts = np.array([lebron_james_free_throw_attempts, joe_johnson_free_throw_attempts, kobe_bryant_free_throw_attempts, carmelo_anthony_free_throw_attempts, dwight_howard_free_throw_attempts, chris_bosh_free_throw_attempts, chris_paul_free_throw_attempts])

# %%
FieldGoals
# Out:
# array([[10, 12, 11,  9, 15, 14, 13, 16, 12, 11],
#        [ 8,  9, 10, 11,  7, 10,  9,  8, 10, 11],
#        [15, 14, 18, 17, 16, 20, 19, 18, 17, 16],
#        [11, 12, 13, 10, 11, 14, 15, 12, 10, 13],
#        [ 5,  6,  7,  8,  6,  5,  7,  6,  8,  7],
#        [ 8,  9,  8,  7, 10,  9, 11, 10,  9,  8],
#        [ 9, 10, 11,  8,  7, 12, 11, 10,  9,  8]])

# %%
np.round(FieldGoalAttempts/FieldGoals)
# Out:
# array([[2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 1., 2., 2., 2., 1., 2., 1., 1.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [1., 1., 1., 2., 1., 1., 1., 1., 1., 2.]])

# %%
salary
# Out:
# array([[15950000., 17720000., 19490000., 21260000., 23030000., 24810000.,
#         25240000., 27850000., 30450000., 30450000.],
#        [ 4620000.,  5830000., 13040000., 14410000., 15780000., 16820000.,
#         16020000., 17550000., 19070000., 20590000.],
#        [ 4500000.,  4900000.,  5360000.,  6050000., 14980000., 15220000.,
#         18030000., 19750000., 21470000., 23180000.],
#        [ 3710000.,  4690000., 13040000., 14410000., 15780000., 17140000.,
#         18520000., 19450000., 21390000., 22450000.],
#        [ 4170000.,  4460000.,  5370000., 13760000., 15200000., 16640000.,
#         17890000., 19260000., 20510000., 21440000.],
#        [ 3130000.,  4180000., 12050000., 14410000., 15780000., 16020000.,
#         16020000., 17550000., 19070000., 20590000.],
#        [ 3140000.,  3380000.,  4570000., 13750000., 14940000., 15800000.,
#         16360000., 17780000., 18670000., 20060000.]])

# %%
salary[0]
# Out:
# array([15950000., 17720000., 19490000., 21260000., 23030000., 24810000.,
#        25240000., 27850000., 30450000., 30450000.])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(salary[0])
plt.show()

# %%
plt.plot(salary[0], c = 'red')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,6

# %%
import matplotlib.pyplot as plt
plt.plot(salary[0],c = 'Blue',ls= '--')
plt.show()

# %%
plt.plot(salary[0],c = 'Green' , ls = '--',marker = 's')

# %%
plt.plot(salary[0],c = 'Green' , ls = '--',marker = 's',ms =7 ) #Marker Square Shaoe Size 7 
plt.xticks(list(range(0,10)),Seasons)
plt.show()

# %%
plt.plot(salary[0], c  = 'Red', ls =  '--' , marker = 's', ms=7, label = 'kobe_bryant_salaries')
plt.plot(salary[1], c  = 'Blue', ls = '--' , marker = 'o', ms=7, label = 'lebron_james_salaries')
plt.plot(salary[2],c = 'Green',ls = '--',marker = 'd',ms=7,label = 'joe_johnson_salaries')
plt.plot(salary[3],c = 'Pink',ls = '--',marker = '^', label = 'Third Person')
plt.xticks(range(0,10),Seasons,rotation = 'vertical')
plt.legend(bbox_to_anchor=(1,0),loc ='upper left')
plt.show()
